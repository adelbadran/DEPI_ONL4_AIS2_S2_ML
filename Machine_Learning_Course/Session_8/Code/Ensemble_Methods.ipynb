# %% [markdown]
# ## Bagging vs. Boosting
# ---

# %%
# Bagging : SubSamples from Rows (Sampling with replacement) - Num of trees
# Random Forest : Bagging + but SubSamples from Features

# %%
# Boosting : 
# HyperParams : Learning Rate, Tree Depth vs. Num of Trees (Trade OFF)

# %% [markdown]
# ## Credit Card Fraud Detection
# ---
